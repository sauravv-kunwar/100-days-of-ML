# %% [markdown]
# # Curse of Dimensionality
#
# - 📈 When the number of features increases, the data space grows extremely fast
#
# - 🧊 Data points become far apart and sparse
#
# - 📏 Distance calculations stop making sense
#
# - 🔍 Finding similar data points becomes difficult
#
# - 🧠 Models need much more data to learn patterns
#
# - ⚠️ High chance of overfitting
#
# - 💻 Training time and memory usage increase
#
# - 📉 Model performance becomes unstable
#
# - 🤖 Distance-based models (k-NN, clustering) suffer the most
#
# - 🛠️ Fixed using feature selection, PCA, or dimensionality reduction
