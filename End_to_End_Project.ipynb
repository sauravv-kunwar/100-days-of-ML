# %%
print("Hello World")
# Out:
# Hello World

# %%
import pandas as pd
df = pd.read_csv("placement.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.tail()
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1

# %%
df.shape
# Out:
# (100, 4)

# %%
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.ndim
# Out:
# 2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'], c = df['placement'])

# %%
# Steps

# 0. Preprocess + EDA + Feature Selection
# 1. Extract input and output cols
# 2. Scale the values
# 3. Train test split
# 4. Train the model
# 5. Evaluate the model/model selection
# 6. Deploy the model

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.ndim
# Out:
# 1

# %%
y.shape
# Out:
# (100,)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 64   7.0   64.0
# 99   6.2  113.0
# 22   4.9  120.0
# 87   5.7  132.0
# 49   5.4  135.0
# ..   ...    ...
# 93   6.8  112.0
# 8    6.1  156.0
# 6    5.7  143.0
# 68   4.0   75.0
# 18   4.0  100.0
#
# [90 rows x 2 columns]

# %%
x_test
# Out:
#     cgpa     iq
# 80   4.9  196.0
# 86   5.1  128.0
# 21   7.1  151.0
# 48   6.6  138.0
# 47   5.2  161.0
# 70   6.3  127.0
# 4    5.8  142.0
# 42   7.6   89.0
# 5    7.1   48.0
# 2    5.3  121.0

# %%
y_train
# Out:
# 64    1
# 99    1
# 22    0
# 87    1
# 49    0
#      ..
# 93    1
# 8     0
# 6     0
# 68    0
# 18    0
# Name: placement, Length: 90, dtype: int64

# %%
y_test
# Out:
# 80    0
# 86    0
# 21    1
# 48    1
# 47    0
# 70    1
# 4     0
# 42    1
# 5     1
# 2     0
# Name: placement, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 0.88126611, -1.47641561],
#        [ 0.19082911, -0.24723063],
#        [-0.931131  , -0.07163278],
#        [-0.24069401,  0.22939212],
#        [-0.49960788,  0.30464834],
#        [ 1.14017998, -0.17197441],
#        [ 0.01821987, -1.42624479],
#        [ 1.31278923, -1.55167183],
#        [-1.19004488,  0.58058783],
#        [ 0.88126611,  0.40498997],
#        [-0.49960788, -0.22214522],
#        [ 2.17583547, -0.07163278],
#        [ 0.10452449, -1.4513302 ],
#        [ 0.44974299,  0.1792213 ],
#        [ 2.00322623,  1.13246679],
#        [ 1.74431235, -1.10013449],
#        [ 0.44974299,  0.93178353],
#        [-2.31200499,  1.50874791],
#        [-0.75852175, -1.42624479],
#        [ 0.36343836,  0.45516079],
#        [ 1.14017998, -1.82761132],
#        [-0.67221713, -0.82419501],
#        [-0.67221713, -0.32248685],
#        [-1.01743563,  0.45516079],
#        [ 0.44974299, -0.82419501],
#        [ 0.53604761, -0.07163278],
#        [ 0.88126611,  1.91011443],
#        [ 1.14017998, -0.92453664],
#        [ 1.83061698,  0.65584405],
#        [ 0.01821987,  0.02870886],
#        [ 0.70865686,  0.45516079],
#        [-1.01743563,  1.1575522 ],
#        [ 1.83061698,  1.08229598],
#        [ 0.88126611,  1.30806465],
#        [ 0.62235224,  1.4836625 ],
#        [-0.75852175,  1.33315006],
#        [ 0.79496148,  0.40498997],
#        [ 1.5717031 , -0.22214522],
#        [ 0.10452449, -1.04996368],
#        [-1.10374025, -0.89945123],
#        [-1.10374025, -0.04654737],
#        [-0.67221713,  0.22939212],
#        [ 0.70865686, -0.82419501],
#        [-0.24069401,  0.43007538],
#        [ 0.10452449,  0.22939212],
#        [-1.44895875,  1.93519984],
#        [-0.931131  ,  0.27956293],
#        [ 1.14017998,  0.35481916],
#        [-1.01743563,  1.00703976],
#        [ 1.31278923,  0.88161272],
#        [-0.84482638, -0.7991096 ],
#        [ 0.36343836, -0.17197441],
#        [-0.931131  ,  0.80635649],
#        [-0.67221713,  2.53724963],
#        [-0.06808476, -0.42282848],
#        [-1.10374025, -1.7774405 ],
#        [ 0.62235224,  0.78127109],
#        [-0.931131  , -1.55167183],
#        [-0.84482638, -0.12180359],
#        [ 1.22648461,  0.22939212],
#        [ 0.88126611, -0.27231604],
#        [-1.01743563, -0.27231604],
#        [-0.15438938,  1.08229598],
#        [ 0.44974299, -2.15372162],
#        [-0.931131  ,  0.70601486],
#        [ 0.01821987, -0.52317011],
#        [ 0.27713374, -0.49808471],
#        [ 1.31278923,  0.1792213 ],
#        [ 0.79496148,  0.37990456],
#        [-1.36265412, -2.02829458],
#        [ 0.70865686,  0.00362345],
#        [-0.49960788, -0.39774308],
#        [-0.84482638, -1.50150101],
#        [ 0.01821987, -1.95303835],
#        [ 0.01821987,  0.65584405],
#        [-2.13939574,  2.7630183 ],
#        [-0.49960788,  0.40498997],
#        [ 0.27713374,  0.12905049],
#        [ 0.10452449, -0.49808471],
#        [ 0.79496148, -0.67368256],
#        [-1.79417725, -0.34757226],
#        [-0.58591251, -0.22214522],
#        [ 1.39909385,  0.12905049],
#        [-0.24069401,  1.1575522 ],
#        [-1.36265412,  0.65584405],
#        [ 0.70865686, -0.27231604],
#        [ 0.10452449,  0.8314419 ],
#        [-0.24069401,  0.5053316 ],
#        [-1.70787262, -1.20047612],
#        [-1.70787262, -0.57334093]])

# %%
x_test = scaler.fit_transform(x_test)

# %%
x_test
# Out:
# array([[-1.30005417,  1.73271724],
#        [-1.08337848, -0.05521557],
#        [ 1.08337848,  0.54952641],
#        [ 0.54168924,  0.20771572],
#        [-0.97504063,  0.8124577 ],
#        [ 0.2166757 , -0.0815087 ],
#        [-0.32501354,  0.31288824],
#        [ 1.62506771, -1.08064763],
#        [ 1.08337848, -2.15866594],
#        [-0.86670278, -0.23926748]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
#Model Training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
clf.predict(x_test)
# Out:
# array([0, 0, 1, 1, 0, 1, 0, 1, 1, 0])

# %%
y_test
# Out:
# 80    0
# 86    0
# 21    1
# 48    1
# 47    0
# 70    1
# 4     0
# 42    1
# 5     1
# 2     0
# Name: placement, dtype: int64

# %%
# To find the accuracy
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
# !pip install mlxtend
# Out:
# zsh:1: command not found: pip

# %%
from mlxtend.plotting import plot_decision_regions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 from mlxtend.plotting import plot_decision_regions
#
# ModuleNotFoundError: No module named 'mlxtend'

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
#
# NameError: name 'plot_decision_regions' is not defined
